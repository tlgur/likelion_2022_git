# %% [markdown]
# # 10기 멋쟁이 사자처럼 python 패키지 과제_정답
# <br>
# <div style = "font-weight: 800;">
# <ol>
# <li>이름: </li>
# <li>학번: </li>
# <li>학과: </li>
# <li>일시: </li>
# <br>
# <ol>
# </div>
#
# <h3>크롤링하기:</h3>

# %% [markdown]
# ## Problem1
# ### 문제1
# <div style = "margin-top:30px">
# 영화 목록 API를 이용하여 감독의 이름이 "봉준호"인 영화의 목록을 받아 데이터 프레임을 생성한 후, 'prdtYear'변수를 기준으로 오름차순을 정렬하세요. 'directors'컬럼과 'companys'컬럼은 이름만 남도록 변경해주세요.
# </div>

# %%
#from urllib.parse import urlencode, quote_plus
import requests
import pandas as pd
from bs4 import BeautifulSoup
import bs4
import json

key = 'a8e597633acca03091ad5fba598b58a7'
url = "http://kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key=" + key
parameter = {"directorNm": "봉준호"}
req = requests.get(url, parameter)
#공공데이터에 등록된 xml파일에 접
html= req.json()
html
DF = pd.DataFrame(html['movieListResult']["movieList"])
## 연도로 다시 정렬
DF = DF.sort_values("prdtYear")

## 컬럼 형식 바꾸기
DF['directors'] = DF['directors'].apply(lambda x : x[0]['peopleNm'])
DF['companys'] = DF['companys'].apply(lambda x : x[0]['companyNm'] if x else x)

DF
# Out:
#     movieCd  movieNm                movieNmEn prdtYear    openDt typeNm  \
# 1  20100457     지리멸렬              Incoherence     1994               단편
# 2  20149067      백색인             White Collar     1994               단편
# 9  20000024  플란다스의 개  Barking Dogs Never Bite     2000  20000219     장편
# 5  20030046   살인의 추억       Memories of Murder     2003  20030425     장편
# 0  20072091    인플루엔자                Influenza     2004               단편
# 6  20060151       괴물                 The Host     2006  20060727     장편
# 4  20090248       마더                   Mother     2009  20090528     장편
# 7  20126674     설국열차              Snowpiercer     2013  20130801     장편
# 8  20158485       옥자                     Okja     2017  20170629     장편
# 3  20183782      기생충                 PARASITE     2019  20190530     장편
#
#   prdtStatNm nationAlt     genreAlt repNationNm repGenreNm directors  \
# 1         기타        한국          코미디          한국        코미디       봉준호
# 2         기타        한국           기타          한국         기타       봉준호
# 9         개봉        한국      드라마,코미디          한국        드라마       봉준호
# 5         개봉        한국          스릴러          한국        스릴러       봉준호
# 0         기타        한국          드라마          한국        드라마       봉준호
# 6         개봉        한국    SF,가족,드라마          한국         SF       봉준호
# 4         개봉        한국          드라마          한국        드라마       봉준호
# 7         개봉     한국,체코        SF,액션          한국         SF       봉준호
# 8         개봉        미국  어드벤처,액션,드라마          미국       어드벤처       봉준호
# 3         개봉        한국          드라마          한국        드라마       봉준호
#
#       companys
# 1     한국영화아카데미
# 2           []
# 9         우노필름
# 5      (주)싸이더스
# 0           []
# 6    영화사청어람(주)
# 4   (주)바른손이앤에이
# 7      (주)모호필름
# 8  플랜 비 엔터테인먼트
# 3   (주)바른손이앤에이

# %% [markdown]
# ### 문제2:
# <div style = "margin-top:30px">
#
# 일별 박스오피스 API를 이용하여 2018년의 한국 영화 일별 박스오피스 데이터를 생성하여 csv파일로 저장하세요.
# </div>

# %%
## 날짜를 먼저 만들어준다. -> 시간 데이터 만들기
date = pd.date_range('20180101', '20181231')
date

Time = []
for time in date:    
    Time.append(date.strftime("%Y%m%d").tolist())
    
time_list=Time[0] ##12번 반복됨을 알아서 그중에서 하나만 사용

# %%
requestData2 = requests.get(url+str(time_list[k])+'')
data_2 = requestData2.json()
data = data_2['boxOfficeResult']['dailyBoxOfficeList']
df = pd.DataFrame.from_dict(data)
df_default = df_default.append(df)
df_default
# Out:
#    rnum rank rankInten rankOldAndNew   movieCd            movieNm      openDt  \
# 0     1    1         0           OLD  20150976          신과함께-죄와 벌  2017-12-20
# 1     2    2         0           OLD  20170590               1987  2017-12-27
# 2     3    3         0           OLD  20170402                강철비  2017-12-14
# 3     4    4         0           OLD  20179462             위대한 쇼맨  2017-12-20
# 4     5    5         0           OLD  20174965  극장판 포켓몬스터 너로 정했다!  2017-12-21
# ..  ...  ...       ...           ...       ...                ...         ...
# 5     6    6         1           OLD  20173202                 버닝  2018-05-17
# 6     7    7         2           OLD  20182046          안녕, 나의 소녀  2018-05-16
# 7     8    8        -3           OLD  20183084              피터 래빗  2018-05-16
# 8     9    9         0           NEW  20184132       세라비, 이것이 인생!  2018-05-30
# 9    10   10        26           OLD  20178424             레이디 버드  2018-04-04
#
#       salesAmt salesShare  salesInten salesChange     salesAcc audiCnt  \
# 0   7715149100       52.9  -853021100         -10  76065645532  916652
# 1   4460462100       30.6  -224621200        -4.8  19714466137  531469
# 2    944228600        6.5   -48816300        -4.9  32939126166  114298
# 3    509947700        3.5    25348100         5.2   7166974900   60070
# 4    262886500        1.8    -7375400        -2.7   3380416200   34103
# ..         ...        ...         ...         ...          ...     ...
# 5     69750600        3.2   -86053000       -55.2   4104944098    8382
# 6     12666500        0.6   -25944000       -67.2    732960934    1667
# 7     11733600        0.5  -289451500       -96.1   2410607300    1589
# 8      3888000        0.2     3888000         100     23598000     972
# 9      7034000        0.3     5967500       559.5    818648000     791
#
#    audiInten audiChange  audiAcc scrnCnt showCnt
# 0    -107305      -10.5  9456147    1644    7957
# 1     -28577       -5.1  2473546    1097    4982
# 2      -6548       -5.4  4128591     602    1451
# 3       2402        4.2   874655     432     843
# 4      -1037         -3   449358     417     605
# ..       ...        ...      ...     ...     ...
# 5      -8186      -49.4   457234     435     935
# 6      -3021      -64.4    93511     109     223
# 7     -36215      -95.8   311513     233     293
# 8        972        100     3051       2       3
# 9        680      612.6   100692       6       7
#
# [1110 rows x 18 columns]

# %%
data = []
key = 'a8e597633acca03091ad5fba598b58a7'
url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=" + key + "&targetDt="
df_default = pd.DataFrame()
for k in range(len(time_list)):
    requestData2 = requests.get(url+str(time_list[k])+'')
    try: 
        data_2 = requestData2.json()
        data = data_2['boxOfficeResult']['dailyBoxOfficeList']
        df = pd.DataFrame.from_dict(data)
        df_default = df_default.append(df)
    except:
        pass

# %%
df_default.to_csv('data_result.csv',encoding='utf-8', index = False) ## 한글이 포함되어 있으므로, encoding에 utf-8을 넣는다.-> 파일을 저장한다.

# %%
## 출력을 통해서 확인
pd.read_csv('data_result.csv')
# Out:
#       rnum  rank  rankInten rankOldAndNew   movieCd  \
# 0        1     1          0           OLD  20150976
# 1        2     2          0           OLD  20170590
# 2        3     3          0           OLD  20170402
# 3        4     4          0           OLD  20179462
# 4        5     5          0           OLD  20174965
# ...    ...   ...        ...           ...       ...
# 2765     6     6          0           OLD  20183785
# 2766     7     7          1           OLD  20182421
# 2767     8     8         -1           OLD  20168773
# 2768     9     9          0           OLD  20183479
# 2769    10    10          0           OLD  20183238
#
#                               movieNm      openDt    salesAmt  salesShare  \
# 0                           신과함께-죄와 벌  2017-12-20  2205440800        44.5
# 1                                1987  2017-12-27  1643436600        33.1
# 2                                 강철비  2017-12-14   358149600         7.2
# 3                              위대한 쇼맨  2017-12-20   269239500         5.4
# 4                   극장판 포켓몬스터 너로 정했다!  2017-12-21   123797500         2.5
# ...                               ...         ...         ...         ...
# 2765            점박이 한반도의 공룡2 : 새로운 낙원  2018-12-25   297544650         4.3
# 2766                              그린치  2018-12-19   185433950         2.7
# 2767                              마약왕  2018-12-19   209406100         3.0
# 2768  극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~  2018-12-19   123978500         1.8
# 2769                    스파이더맨: 뉴 유니버스  2018-12-12    91504350         1.3
#
#       salesInten  salesChange     salesAcc  audiCnt  audiInten  audiChange  \
# 0    -5509708300        -71.4  78271086332   294339    -622313       -67.9
# 1    -2817025500        -63.2  21357902737   217247    -314222       -59.1
# 2     -586079000        -62.1  33297275766    48122     -66176       -57.9
# 3     -240708200        -47.2   7436214400    35177     -24893       -41.4
# 4     -139089000        -52.9   3504213700    17929     -16174       -47.4
# ...          ...          ...          ...      ...        ...         ...
# 2765  -167912650        -36.1   2941541400    41686     -15948       -27.7
# 2766   -67594250        -26.7   3675441950    26250      -5453       -17.2
# 2767   -92312800        -30.6  15784724552    25769      -7205       -21.9
# 2768   -82081550        -39.8   2148708050    17453      -8701       -33.3
# 2769   -25207850        -21.6   5305289076    11607      -1417       -10.9
#
#       audiAcc  scrnCnt  showCnt
# 0     9750486     1446     7019
# 1     2690793     1063     5044
# 2     4176713      580     1541
# 3      909832      444      949
# 4      467287      371      510
# ...       ...      ...      ...
# 2765   375312      553      943
# 2766   485064      446      635
# 2767  1813594      533     1178
# 2768   277206      269      370
# 2769   639934      152      270
#
# [2770 rows x 18 columns]

# %% [markdown]
# ## Problem2
# ### 문제 1:
# <div style = "margin-top:30px">
#
# 멜론의 Top100 차트 데이터를 크롤링해 곡 명, 가수 명, 앨범 명 데이터를 만들어 봅시다.
# </div>

# %%
import selenium
from selenium import webdriver as wd
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests
from itertools import repeat

# %%
driver = wd.Chrome('.\chromedriver') # 크롬드라이버 경로
driver.maximize_window() # 크롬창 크기 최대

# 드라이버가 해당 url 접속
url = 'https://www.melon.com/chart/index.htm' # 멜론차트 페이지
driver.get(url)

html = driver.page_source # 드라이버 현재 페이지의 html 정보 가져오기 
                        # cf) requests.get(url)
soup = BeautifulSoup(html, 'html.parser')

title = soup.find_all('div', class_ = 'ellipsis rank01')
singer = soup.find_all('span', class_ = 'checkEllipsis')
album = soup.find_all('div', class_ = 'ellipsis rank03')

title_list = []
singer_list = []
album_list = []

length  = len(title) # 100
for i in range(0, length, 1):
    title_list.append(title[i].text.strip("\n"))
    singer_list.append(singer[i].text)  
    album_list.append(album[i].text.strip("\n"))


df_1= pd.DataFrame()
df_1['title'] = title_list
df_1['singer'] = singer_list
df_1['album'] = album_list

df_1
driver.close()
# Out:
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/1618663593.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('.\chromedriver') # 크롬드라이버 경로

# %%
df_1
# Out:
#                    title             singer  \
# 0   봄여름가을겨울 (Still Life)       BIGBANG (빅뱅)
# 1              LOVE DIVE          IVE (아이브)
# 2                 TOMBOY            (여자)아이들
# 3                 사랑인가 봐               멜로망스
# 4         Feel My Rhythm  Red Velvet (레드벨벳)
# ..                   ...                ...
# 95  Can't Control Myself       태연 (TAEYEON)
# 96           나는 트로트가 싫어요                임창정
# 97               그대가 있기에                 노을
# 98      벚꽃이 피면 우리 그만 헤어져                  벤
# 99                 벚꽃 엔딩            버스커 버스커
#
#                                         album
# 0                        봄여름가을겨울 (Still Life)
# 1                                   LOVE DIVE
# 2                                 I NEVER DIE
# 3                    사랑인가 봐 (사내맞선 OST 스페셜 트랙)
# 4   ‘The ReVe Festival 2022 - Feel My Rhythm’
# ..                                        ...
# 95                       Can't Control Myself
# 96                                별거 없던 그 하루로
# 97                                    그대가 있기에
# 98                           벚꽃이 피면 우리 그만 헤어져
# 99                                 버스커 버스커 1집
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 문제 2:
# <div style = "margin-top:30px">
# 월간 차트 페이지에서 2021년 1월부터 12월까지의 월간 차트를 모아 하나의 데이터 프레임을 만드세요. 칼럼은 총 8개로 연, 월, 순위, 순위 변동, 곡 명, 가수 명, 앨범 명, 좋아요 수입니다.
# </div>

# %%
df_reset = pd.DataFrame()## 빈 데이터 프레임 만들기

# %%
def melon(mon):
    global df_reset
        # 크롬드라이버 열기
    driver = wd.Chrome('.\chromedriver') # 크롬드라이버 경로
    driver.maximize_window() # 크롬창 크기 최대

    # 드라이버가 해당 url 접속
    url = 'https://www.melon.com/chart/index.htm' # 멜론차트 페이지
    driver.get(url)

    # 차트파인더 클릭
    driver.find_element_by_xpath('//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()

    # 연대선택, 연도선택, 월선택, 장르선택

    # 월간차트 클릭
    driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/h4[2]/a').click()
    time.sleep(2)

    # 연대선택 2020년대 클릭
    driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[1]/span/label').click()
    time.sleep(2)

    # 연도선택 2021년 클릭
    driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[2]/span/label').click()
    time.sleep(2)

    # 월선택 month월 클릭
    driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[3]/div[1]/ul/li['+str(mon)+']/span/label').click()
    time.sleep(2)

    # 장르선택 종합 클릭
    driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[1]/span/label').click()
    time.sleep(2)

    # 검색버튼 클릭
    driver.find_element_by_xpath('//*[@id="d_srch_form"]/div[2]/button/span/span').click()
    time.sleep(2)

    html = driver.page_source # 드라이버 현재 페이지의 html 정보 가져오기 
                           
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup.prettify()) ## beautiful soup 에서 가져온 html 확인

    # html 내에서 각 테그의 특징을 가져와서 이를 통해서 find_all을 실행한다.
    title = soup.find_all('div', class_ = 'ellipsis rank01')
    singer = soup.find_all('span', class_ = 'checkEllipsis')
    album = soup.find_all('div', class_ = 'ellipsis rank03')
    diff = soup.find_all('span', class_ = 'wrap_rank')
    like = soup.find_all('span', class_ = 'cnt')

    ## 리스트 초기화
    year_list = []
    month_list = []
    rank_list = []
    diff_list = []
    title_list = []
    singer_list = []
    album_list = []
    like_list = []

    length  = len(title) # 100
    for i in range(0, length, 1):

        ## 만들어준 리스트에 append를 통해서 담아준다.
        year_list.append(2021)
        month_list.append(mon)
        rank_list.append(i+1)
        title_list.append(title[i].text.strip("\n").replace("\n", " ")) ## 결과를 보니까 중간에 들어간 \n 존재해서 이를 띄어쓰기로 대체
        singer_list.append(singer[i].text)  
        like_list.append(like[i].text.strip("\n")[4:])
        album_list.append(album[i].text.strip("\n"))
        diff_list.append(diff[i+10]['title'])

    ## 빈 데이터 프레임을 만들어서 담아준다 -> 함수를 돌릴 때, 각 함수에서 나온 결과를 담아놓는 dataframe이 필요
    ## 이를 계속 append 해서 최종 dataframe을 만든다.
    df= pd.DataFrame()
    df["year"] = year_list
    df["month"] = month_list
    df['rank'] = rank_list
    df['diff'] = diff_list
    df['title'] = title_list
    df['singer'] = singer_list
    df['album'] = album_list
    df['like'] = like_list
    
    df_reset = df_reset.append(df) #dataframe 결과를 쌓아주는 역할을 한다.
    driver.close()##드라이버가 여러개 열리면 복잡하므로 사용후 닫아준다.

# %%
df_reset = pd.DataFrame()## 빈 데이터 프레임 만들기
for i in range(1, 13, 1): ## 반복문으로 12개월을 한번에 돌리면 끝
    melon(i)
df_reset = df_reset.reset_index(drop=True)   
df_reset
# Out:
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('.\chromedriver') # 크롬드라이버 경로
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/h4[2]/a').click()
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[1]/span/label').click()
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[2]/span/label').click()
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[3]/div[1]/ul/li['+str(mon)+']/span/label').click()
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[1]/span/label').click()
# C:\Users\system1\AppData\Local\Temp/ipykernel_31380/119999246.py:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="d_srch_form"]/div[2]/button/span/span').click()
#       year  month  rank     diff  \
# 0     2021      1     1    순위 동일
# 1     2021      1     2   2단계 상승
# 2     2021      1     3   1단계 하락
# 3     2021      1     4   1단계 하락
# 4     2021      1     5   2단계 상승
# ...    ...    ...   ...      ...
# 1195  2021     12    96    순위 집입
# 1196  2021     12    97  28단계 하락
# 1197  2021     12    98  24단계 하락
# 1198  2021     12    99    순위 집입
# 1199  2021     12   100  28단계 하락
#
#                                                   title  \
# 0                VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 1                                         밤하늘의 별을(2020)
# 2                                              Dynamite
# 3                                             잠이 오질 않네요
# 4                                        Lovesick Girls
# ...                                                 ...
# 1195                UP해 (Feat. 박재범, 우원재) (Prod. 코드 쿤스트)
# 1196                                          잠이 오질 않네요
# 1197                                             오래된 노래
# 1198                                          밤새 서로 미루다
# 1199  19금 Hey Mama (Feat. Nicki Minaj, Bebe Rexha & ...
#
#                                                  singer  \
# 0     미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베...
# 1                                                    경서
# 2                                                 방탄소년단
# 3                                                   장범준
# 4                                             BLACKPINK
# ...                                                 ...
# 1195                                              SINCE
# 1196                                                장범준
# 1197                                             스탠딩 에그
# 1198                                            존박, 전미도
# 1199                                       David Guetta
#
#                            album     like
# 0              쇼미더머니 9 Episode 1  199,030
# 1                  밤하늘의 별을(2020)  186,500
# 2     Dynamite (DayTime Version)  431,700
# 3                      잠이 오질 않네요  156,814
# 4                      THE ALBUM  213,024
# ...                          ...      ...
# 1195              쇼미더머니 10 Final   16,787
# 1196                   잠이 오질 않네요  156,814
# 1197                      오래된 노래  244,868
# 1198                   밤새 서로 미루다   19,176
# 1199                      Listen   62,619
#
# [1200 rows x 8 columns]
